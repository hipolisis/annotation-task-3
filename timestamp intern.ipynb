# %% [markdown]
# ### Annotation Task 3 - Timestamp

# %% [markdown]
# 1. Refueling ✔
#     * **{Vehicle, Carrycan}**
#     * Start Annotation
#         * Vehicle → When the vehicle touches the refueling box (the front of the vehicle, **not the tire**)
#         * Carrycan → one second before the person touches the nozzle
#     * Stop Annotation
#         * Vehicle → Before the vehicle leaves the refueling box (the back of the vehicle, **not the tire**)
#         * Carrycan → one second after nozzle up stop time

# %% [markdown]
# 2. Door open (only when nozzle is UP); When refueling occurs
#     * **{Vehicle}**
#     * Start Annotation → When the person touches the nozzle (to pick it up)
#     * Stop Annotation → When the person close the door

# %% [markdown]
# 3. nozzle up ✔
#     * **{Vehicle, Carrycan}**
#     * Start Annotation
#         * Vehicle, Carrycan → When the person touches the nozzle (to pick it up)
#     * Stop Annotation
#         * Vehicle, Carrycan → When the person has completed the refueling; Annotate it before the person remove the nozzle a.k.a When the person still holds the nozzle
#         ![image.png](attachment:image.png)

# %% [markdown]
# 4. nozzle insertion ✔
#     * **{Vehicle}**
#     * Start Annotation → When the nozzle is inserted into the vehicle's tank
#     * Stop Annotation → When the nozzle is fully out of the vehicle's tank

# %% [markdown]
# 5. 80% nozzle shut off (person) ✔
#     * **{Vehicle, Carrycan}**
#     * How long does it take for a person to shut off the nozzle
#     * Start Annotation → When the person shut off the nozzle
#     * Stop Annotation → Before the nozzle starts to appear again

# %% [markdown]
# 6. 80% nozzle shut off (~~fuel filler port~~ refueling ports) ✔
#     * **{Vehicle}**
#     * How long does it take for a refueling port to shut off the nozzle
#     * Start Annotation → When the refueling port shut off the nozzle
#     * Stop Annotation → Before the refueling port starts to appear again

# %% [markdown]
# 7. 80% nozzle shutoff (door) ✔
#     * **{Vehicle, Carrycan}**
#     * How long does it take for a door to shut off the nozzle
#     * Start Annotation → When the door shut off the nozzle
#     * Stop Annotation → Before the nozzle starts to appear again

# %% [markdown]
# 8. Refueling Position (pending); the wheel of the vehicle suddenly move from initial refueling or rectangular area
#     * **{Vehicle}**
#     * Start Annotation →
#     * Stop Annotation →

# %% [markdown]
# 9. Let go of the nozzle ✔
#     * **{Vehicle, Carrycan}**
#     * How long does it take for a person to let go of the nozzle
#     * Start Annotation → After the person doesn't touch the nozzle
#     * Stop Annotation → Before the person touches the nozzle again

# %% [markdown]
# 10. Multiple person refueling ✔
#     * **{Vehicle, Carrycan}**
#     * How long does it take for multiple people to go in and out of the refueling area
#     * Start Annotation → When the second/third/fourth/.. person appears in the refueling area
#     * Stop Annotation → Before the second/third/fourth/.. person disappears in the refueling area

# %% [markdown]
# 11. Stopping outside the parking frame
#     * Start Annotation →
#     * Stop Annotation →

# %% [markdown]
# 12. portable can detection ✔
#     * **{Carrycan}**
#     * Start Annotation → Start time of `Refueling` ~~One second / two seconds after nozzle up~~
#     * Stop Annotation → End time of `Refueling`

# %% [markdown]
# 13. portable can refueling ✔
#     * **{Carrycan}**
#     * Start Annotation → When the nozzle is inserted to the Carrycan
#     * Stop Annotation → One second before the nozzle is fully out of the Carrycan

# %% [markdown]
# 14. smoking
#     * Start Annotation →
#     * Stop Annotation →

# %% [markdown]
# 15. fire (open door)
#     * for any door opened (front / back / rear door)
#     * Start Annotation → When the person exits the vehicle (front door is opened a little bit)
#     * Stop Annotation → When the person is fully closed the door

# %% [markdown]
# 16. 80% of refueling ports shut off (~~people~~ person) ✔
#     * **{Vehicle}**
#     * How long does it take for a person to shut off the refueling port
#     * Start Annotation → When the person shut off the refueling port
#     * Stop Annotation → Before the refueling port starts to appear again
# ![image.png](attachment:image.png)

# %% [markdown]
# 17. 80% of fuel filler openings blocked (door) ✔
#     * **{Vehicle, Carrycan}**
#     * How long does it take for a door to shut off the fuel filler opening
#     * Start Annotation → When the person shut off the fuel filler opening
#     * Stop Annotation → Before the fuel filler opening starts to appear again
#     ![image.png](attachment:image.png)
